# %%
import requests

# %%
url = 'http://172.16.12.149:8080/corona'
param = {
    'id': '문병선', 
    'password': '1111'
}

result = requests.get(url, params=param)
print(result.text)

# %%
import pandas as pd

# %%
result.json()
# Out:
# [{'createDt': '2022-06-08 09:09:05.982',
#   'deathCnt': 24305,
#   'decideCnt': 18188200,
#   'seq': 904,
#   'stateDt': 20220608,
#   'stateTime': '00:00',
#   'updateDt': None,
#   'accExamCnt': '',
#   'accDefRate': ''},
#  {'createDt': '2022-06-07 09:09:00.897',
#   'deathCnt': 24299,
#   'decideCnt': 18174842,
#   'seq': 903,
#   'stateDt': 20220607,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:10:36.846',
#   'accExamCnt': '',
#   'accDefRate': ''},
#  {'createDt': '2022-06-06 09:00:06.734',
#   'deathCnt': 24279,
#   'decideCnt': 18168670,
#   'seq': 902,
#   'stateDt': 20220606,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:10:50.441',
#   'accExamCnt': '',
#   'accDefRate': ''},
#  {'createDt': '2022-06-05 08:53:19.426',
#   'deathCnt': 24258,
#   'decideCnt': 18163648,
#   'seq': 901,
#   'stateDt': 20220605,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:04.758',
#   'accExamCnt': '',
#   'accDefRate': ''},
# ...

# %%
pd.DataFrame(result.json())
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt accExamCnt   accDefRate
# ...

# %%
pd.DataFrame(result.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.DataFrame(result.text)
#
# File c:\Users\moons\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:780, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     777 # For data is scalar
#     778 else:
#     779     if index is None or columns is None:
# --> 780         raise ValueError("DataFrame constructor not properly called!")
#     782     index = ensure_index(index)
#     783     columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
